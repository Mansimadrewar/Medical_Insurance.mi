# %%
import pandas as pd

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/content/insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
plt.figure(figsize=(12,5))

sns.histplot(df['bmi'],kde=True)
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()


plt.figure(figsize=(10,4))
sns.boxplot(x = df['bmi'])
plt.title('Box plot of BMI')
plt.show()

# %%
#remove the outlier

Q1 = df['bmi'].quantile(0.25)
Q3 = df['bmi'].quantile(0.75)

IQR = Q3-Q1

lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

print(f" lower : {lower_bound}, upper : {upper_bound}")
# Out:
#  lower : 13.7, upper : 47.290000000000006

# %%
#cleaning the outliers

df_cleaned = df[(df['bmi']>=lower_bound) & (df['bmi']<=upper_bound)]

# %%
plt.figure(figsize=(12,5))

sns.histplot(df_cleaned['bmi'],kde=True)
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()


plt.figure(figsize=(10,4))
sns.boxplot(x = df_cleaned['bmi'])
plt.title('Box plot of BMI')
plt.show()

# %%
df_cleaned = pd.get_dummies(df_cleaned,drop_first=True)
df_cleaned
# Out:
#       age     bmi  ...  region_southeast  region_southwest
# 0      19  27.900  ...             False              True
# 1      18  33.770  ...              True             False
# 2      28  33.000  ...              True             False
# 3      33  22.705  ...             False             False
# 4      32  28.880  ...             False             False
# ...   ...     ...  ...               ...               ...
# 1333   50  30.970  ...             False             False
# 1334   18  31.920  ...             False             False
# 1335   18  36.850  ...              True             False
# 1336   21  25.800  ...             False              True
# 1337   61  29.070  ...             False             False
#
# [1329 rows x 9 columns]

# %%
df_cleaned.corr()
# Out:
#                        age       bmi  ...  region_southeast  region_southwest
# age               1.000000  0.114686  ...         -0.011581          0.010474
# bmi               0.114686  1.000000  ...          0.255863          0.000651
# children          0.043041  0.017355  ...         -0.018816          0.020021
# charges           0.302022  0.193196  ...          0.071597         -0.045906
# sex_male         -0.019143  0.039958  ...          0.010263         -0.001195
# smoker_yes       -0.024505 -0.002871  ...          0.068270         -0.039440
# region_northwest -0.000283 -0.128598  ...         -0.344807         -0.323046
# region_southeast -0.011581  0.255863  ...          1.000000         -0.344105
# region_southwest  0.010474  0.000651  ...         -0.344105          1.000000
#
# [9 rows x 9 columns]

# %%
sns.heatmap(df_cleaned.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,5))
sns.heatmap(df_cleaned.corr(),annot=True)
# Out:
# <Axes: >

# %%
df_cleaned.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes',
#        'region_northwest', 'region_southeast', 'region_southwest'],
#       dtype='object')

# %%
x = df_cleaned[['age','bmi','smoker_yes']]
y = df_cleaned['charges']

# %%
#train the splits

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=23)

# %%
#train the model

model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)  # testing on test data
y_train_pred = model.predict(x_train) # testing on train data

# %%
print(f' testing results : {r2_score(y_test,y_pred)}')
print(f' training results : {r2_score(y_train,y_train_pred)}')
# Out:
#  testing results : 0.7387033649370546
#  training results : 0.7472506274309794

# %%
print(f' testing results : {mean_squared_error(y_test,y_pred)}')
print(f' training results : {mean_squared_error(y_train,y_train_pred)}')
# Out:
#  testing results : 31918022.304854628
#  training results : 37656130.688268535

# %%
#raj

model.predict([[23,20,0]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([631.25142274])

# %%
import pickle
model_file = open('model.pkl','wb')
pickle.dump(model,model_file)
model_file.close()
